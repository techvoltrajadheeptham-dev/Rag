# %% [markdown]
# <a href="https://colab.research.google.com/github/techvoltrajadheeptham-dev/Rag/blob/main/Rag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PDF LOADER

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (25.3)

# %%
# !pip install langchain-community --quiet
# !pip install pypdf --quiet

# %%
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("/content/drive/MyDrive/ESDIPTT project book.pdf")
pdf_pages = loader.load()

# %%
pdf_pages[0]
# Out:
# Document(metadata={'producer': 'Acrobat Distiller 4.0 for Windows', 'creator': 'PyPDF', 'creationdate': '1999-05-17T00:46:04+00:00', 'moddate': '2003-09-13T12:35:51-10:00', 'source': '/content/drive/MyDrive/ESDIPTT project book.pdf', 'total_pages': 209, 'page': 0, 'page_label': '1'}, page_content='Embedded Systems Design: An Introduction to Processes, Tools, and \nTechniques \nby Arnold S. Berger ISBN: 1578200733 \nCMP Books © 2002 (237 pages) \nAn easy-to-understand guidebook for those embarking upon an embedded \nprocessor development project.  \n \n \nTable of Contents  \n \n \nEmbedded Systems Design—An Introduc tion to Processes, Tools, and \nTechniques  \n Preface  \n Introduction  \n Chapter 1 - The Embedded Design Life Cycle \n Chapter 2 - The Selection Process \n Chapter 3 - The Partitioning Decision \n Chapter 4 - The Development Environment \n Chapter 5 - Special Software Techniques \n Chapter 6 - A Basic Toolset \n Chapter 7 - BDM, JTAG, and Nexus \n Chapter 8 - The ICE — An Integrated Solution \n Chapter 9 - Testing \n Chapter 10 - The Future \n Index  \n List of Figures  \n List of Tables  \n List of Listings  \n List of Sidebars  \n \nTEAMFLY\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nTeam-Fly\n®')

# %% [markdown]
# YOUTUBE LOADER

# %%
# !pip install yt_dlp -quiet
# !pip install pydub --quiet
# !pip install faster-whisper -quiet
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: -u
#
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: -u

# %%
# !pip install yt_dlp faster-whisper torch torchaudio
# Out:
# Collecting yt_dlp
#   Downloading yt_dlp-2025.11.12-py3-none-any.whl.metadata (180 kB)
# Collecting faster-whisper
#   Downloading faster_whisper-1.2.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Collecting ctranslate2<5,>=4.0 (from faster-whisper)
#   Downloading ctranslate2-4.6.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.21 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.36.0)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.22.1)
# Collecting onnxruntime<2,>=1.14 (from faster-whisper)
#   Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Collecting av>=11 (from faster-whisper)
#   Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (4.67.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.0.2)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.3)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.9.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (2.32.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (1.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21->faster-whisper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21->faster-whisper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21->faster-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21->faster-whisper) (2025.10.5)
# Downloading yt_dlp-2025.11.12-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.8 MB/s  0:00:00
# Downloading faster_whisper-1.2.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.8 MB/s  0:00:00
# Downloading ctranslate2-4.6.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (38.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 29.6 MB/s  0:00:01
# Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 75.1 MB/s  0:00:00
# Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (40.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 34.2 MB/s  0:00:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Installing collected packages: yt_dlp, humanfriendly, ctranslate2, av, coloredlogs, onnxruntime, faster-whisper
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [faster-whisper]
# Successfully installed av-16.0.1 coloredlogs-15.0.1 ctranslate2-4.6.1 faster-whisper-1.2.1 humanfriendly-10.0 onnxruntime-1.23.2 yt_dlp-2025.11.12

# %%
from langchain.document_loaders.generic import GenericLoader
from langchain_community.document_loaders.parsers.audio import FasterWhisperParser
from langchain.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader

# %%
url="https://youtu.be/uFhDGagZzjs?si=13CGCyCKrqVN8i88"
save_dir="doc/youtube"
loader = GenericLoader( YoutubeAudioLoader([url],save_dir), FasterWhisperParser()
)
docs=loader.load()
# Out:
# [youtube] Extracting URL: https://youtu.be/uFhDGagZzjs?si=13CGCyCKrqVN8i88
# [youtube] uFhDGagZzjs: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one. To silence this warning, you can use  --extractor-args "youtube:player_client=default"
# [youtube] uFhDGagZzjs: Downloading android sdkless player API JSON
# [youtube] uFhDGagZzjs: Downloading web safari player API JSON
# WARNING: [youtube] uFhDGagZzjs: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] uFhDGagZzjs: Downloading m3u8 information
# WARNING: [youtube] uFhDGagZzjs: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [info] uFhDGagZzjs: Downloading 1 format(s): 140-5
# [download] Sleeping 4.00 seconds as required by the site...
# [download] Destination: doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a
# [download] 100% of   27.29MiB in 00:00:02 at 12.66MiB/s
# [FixupM4a] Correcting container of "doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a"
# [ExtractAudio] Not converting audio doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a; file is already in target format m4a
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# vocabulary.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.bin:   0%|          | 0.00/145M [00:00<?, ?B/s]

# %%
docs[1]
# Out:
# Document(metadata={'source': 'doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a', 'timestamps': '[24.00s -> 33.76s]', 'language': 'en', 'probability': '96%'}, page_content=' Kamalikadatta. Now in this course we shall be talking about various aspects of embedded system design.')

# %%
len(docs)
# Out:
# 219

# %%
len(pdf_pages)
# Out:
# 209

# %%
combined_docs = pdf_pages + docs

# %%
len(combined_docs)
# Out:
# 428

# %% [markdown]
# CHUNKING

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter

# %%
chunk_size = 1024
chunk_overlap = 200

# %%
splitter = RecursiveCharacterTextSplitter(
chunk_size=chunk_size,
chunk_overlap=chunk_overlap
)

# %%
chunked_docs = splitter.split_documents(combined_docs)

# %%
chunked_docs [0]
# Out:
# Document(metadata={'producer': 'Acrobat Distiller 4.0 for Windows', 'creator': 'PyPDF', 'creationdate': '1999-05-17T00:46:04+00:00', 'moddate': '2003-09-13T12:35:51-10:00', 'source': '/content/drive/MyDrive/ESDIPTT project book.pdf', 'total_pages': 209, 'page': 0, 'page_label': '1'}, page_content='Embedded Systems Design: An Introduction to Processes, Tools, and \nTechniques \nby Arnold S. Berger ISBN: 1578200733 \nCMP Books © 2002 (237 pages) \nAn easy-to-understand guidebook for those embarking upon an embedded \nprocessor development project.  \n \n \nTable of Contents  \n \n \nEmbedded Systems Design—An Introduc tion to Processes, Tools, and \nTechniques  \n Preface  \n Introduction  \n Chapter 1 - The Embedded Design Life Cycle \n Chapter 2 - The Selection Process \n Chapter 3 - The Partitioning Decision \n Chapter 4 - The Development Environment \n Chapter 5 - Special Software Techniques \n Chapter 6 - A Basic Toolset \n Chapter 7 - BDM, JTAG, and Nexus \n Chapter 8 - The ICE — An Integrated Solution \n Chapter 9 - Testing \n Chapter 10 - The Future \n Index  \n List of Figures  \n List of Tables  \n List of Listings  \n List of Sidebars  \n \nTEAMFLY\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nTeam-Fly\n®')

# %%
len(chunked_docs)
# Out:
# 897

# %% [markdown]
# Embeddings

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
multilingual_embeddings = HuggingFaceEmbeddings(model_name='intfloat/multilingual-e5-large')
# Out:
# /tmp/ipython-input-1839380797.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   multilingual_embeddings = HuggingFaceEmbeddings(model_name='intfloat/multilingual-e5-large')
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/201 [00:00<?, ?B/s]

# %% [markdown]
# VECTOR DB

# %%
# !pip install chromadb --quiet

# %%
from langchain.vectorstores import Chroma

# %%
persist_directory = "/db/chroma/"

# %%
vectordb = Chroma.from_documents(
    documents=chunked_docs,
    embedding = multilingual_embeddings,
    persist_directory=persist_directory
)

# %%
question = "How to do testing in the embedded systems?"

# %%
vectordb.similarity_search(question, k=3)
# Out:
# [Document(metadata={'language': 'en', 'probability': '96%', 'timestamps': '[1144.16s -> 1156.96s]', 'source': 'doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a'}, page_content='respond to the inputs. Now how can we define an embedded system based on whatever we talked about'),
#  Document(metadata={'timestamps': '[1641.12s -> 1647.44s]', 'probability': '96%', 'language': 'en', 'source': 'doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a'}, page_content="respond to user's needs automatically. These are all examples of embedded systems."),
#  Document(metadata={'timestamps': '[469.36s -> 477.60s]', 'source': 'doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a', 'language': 'en', 'probability': '96%'}, page_content='Now talking about this embedded systems again what are these embedded systems? I already')]

# %%
vectordb.similarity_search_with_score(question, k=3)
# Out:
# [(Document(metadata={'language': 'en', 'source': 'doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a', 'probability': '96%', 'timestamps': '[1144.16s -> 1156.96s]'}, page_content='respond to the inputs. Now how can we define an embedded system based on whatever we talked about'),
#   0.25008562207221985),
#  (Document(metadata={'source': 'doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a', 'probability': '96%', 'language': 'en', 'timestamps': '[1641.12s -> 1647.44s]'}, page_content="respond to user's needs automatically. These are all examples of embedded systems."),
#   0.27293840050697327),
#  (Document(metadata={'probability': '96%', 'timestamps': '[469.36s -> 477.60s]', 'language': 'en', 'source': 'doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a'}, page_content='Now talking about this embedded systems again what are these embedded systems? I already'),
#   0.27566471695899963)]

# %% [markdown]
# RETRIVAL

# %%
vectordb.max_marginal_relevance_search(question, k=3, fetch_k=10)
# Out:
# [Document(metadata={'language': 'en', 'probability': '96%', 'source': 'doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a', 'timestamps': '[1144.16s -> 1156.96s]'}, page_content='respond to the inputs. Now how can we define an embedded system based on whatever we talked about'),
#  Document(metadata={'creationdate': '1999-05-17T00:46:04+00:00', 'moddate': '2003-09-13T12:35:51-10:00', 'total_pages': 209, 'producer': 'Acrobat Distiller 4.0 for Windows', 'creator': 'PyPDF', 'page': 165, 'source': '/content/drive/MyDrive/ESDIPTT project book.pdf', 'page_label': '166'}, page_content='some way to measure how well our tests are covering the code and to identify the \nsections of code that are not yet being exercised. \nThe following sections describe several techniques for measuring test coverage. \nSome are software-based, and some exploit the emulators and integrated device \nelectronics (IDE) that are often available to embedded systems engineers.'),
#  Document(metadata={'creator': 'PyPDF', 'page': 156, 'page_label': '157', 'producer': 'Acrobat Distiller 4.0 for Windows', 'creationdate': '1999-05-17T00:46:04+00:00', 'source': '/content/drive/MyDrive/ESDIPTT project book.pdf', 'total_pages': 209, 'moddate': '2003-09-13T12:35:51-10:00'}, page_content='Chapter 9: Testing \nEmbedded systems software testing shares much in common with application \nsoftware testing. Thus, much of this chapter is a summary of basic testing \nconcepts and terminology. However, some important differences exist between \napplication testing and embedded systems testing. Embedded developers often \nhave access to hardware-based test tools that are generally not used in application \ndevelopment. Also, embedded systems often have unique characteristics that \nshould be reflected in the test plan. These differences tend to give embedded \nsystems testing its own distinctive flavor. This chapter covers the basics of testing \nand test case development and points out details unique to embedded systems \nwork along the way. \nWhy Test? \nBefore you begin designing tests, it’s important to have a clear understanding of \nwhy you are testing. This understanding influences which tests you stress and \n(more importantly) how early you begin testing. In general, you test for four \nreasons:')]

# %% [markdown]
# META DATA FILTERING

# %%
vectordb.similarity_search(
    question,
    k=3,
    filter={"source":"/content/drive/MyDrive/ESDIPTT project book.pdf"}
)
# Out:
# [Document(metadata={'producer': 'Acrobat Distiller 4.0 for Windows', 'total_pages': 209, 'source': '/content/drive/MyDrive/ESDIPTT project book.pdf', 'creationdate': '1999-05-17T00:46:04+00:00', 'page_label': '166', 'moddate': '2003-09-13T12:35:51-10:00', 'creator': 'PyPDF', 'page': 165}, page_content='some way to measure how well our tests are covering the code and to identify the \nsections of code that are not yet being exercised. \nThe following sections describe several techniques for measuring test coverage. \nSome are software-based, and some exploit the emulators and integrated device \nelectronics (IDE) that are often available to embedded systems engineers.'),
#  Document(metadata={'total_pages': 209, 'source': '/content/drive/MyDrive/ESDIPTT project book.pdf', 'creator': 'PyPDF', 'producer': 'Acrobat Distiller 4.0 for Windows', 'page': 156, 'page_label': '157', 'creationdate': '1999-05-17T00:46:04+00:00', 'moddate': '2003-09-13T12:35:51-10:00'}, page_content='Chapter 9: Testing \nEmbedded systems software testing shares much in common with application \nsoftware testing. Thus, much of this chapter is a summary of basic testing \nconcepts and terminology. However, some important differences exist between \napplication testing and embedded systems testing. Embedded developers often \nhave access to hardware-based test tools that are generally not used in application \ndevelopment. Also, embedded systems often have unique characteristics that \nshould be reflected in the test plan. These differences tend to give embedded \nsystems testing its own distinctive flavor. This chapter covers the basics of testing \nand test case development and points out details unique to embedded systems \nwork along the way. \nWhy Test? \nBefore you begin designing tests, it’s important to have a clear understanding of \nwhy you are testing. This understanding influences which tests you stress and \n(more importantly) how early you begin testing. In general, you test for four \nreasons:'),
#  Document(metadata={'source': '/content/drive/MyDrive/ESDIPTT project book.pdf', 'page_label': '28', 'producer': 'Acrobat Distiller 4.0 for Windows', 'total_pages': 209, 'creator': 'PyPDF', 'creationdate': '1999-05-17T00:46:04+00:00', 'moddate': '2003-09-13T12:35:51-10:00', 'page': 27}, page_content='application ran long enough, the PC would run out of heap space, and the \ncomputer would crash. However, on a desktop machine with 64MB of RAM and \nvirtual swap space, this is unlikely to be a problem. On the other side, in an \nembedded system, running continuously for weeks at a time, even a small \nmemory leak is potentially disastrous. \nWho Does the Testing? \nIn many companies, the job of testing the embedded product goes to a separate \nteam of engineers and technicians because asking a designer to test his own code \nor product usually results in erratic test results. It also might lead to a “circle the \nwagons” mentality on the part of the design team, who view the testers as a \nroadblock to product release, rather than equal partners trying to prevent a \ndefective product from reaching the customer.')]

# %% [markdown]
# GROQ

# %%
# !pip install langchain-groq --quiet

# %%
import getpass
import os

if "GROQ API_KEY" not in os.environ:
  os.environ ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
# Out:
# Enter your Groq API key: ··········

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0,
    max_tokens=250,
)

# %%
response=llm.invoke("Write a poem on nature")

# %% [markdown]
# PROMPT ENGINEERING

# %%
system_prompt = (
    "You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question."
    "If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise."
    "Answer all questions to the best of your ability."
)

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

# %%
system_message=[SystemMessage(content=system_prompt)]

# %%
question="How to do testing in embedded system?"

# %%
vectordb.similarity_search(question, k=3)
# Out:
# [Document(metadata={'probability': '96%', 'timestamps': '[1144.16s -> 1156.96s]', 'language': 'en', 'source': 'doc/youtube/Lecture 01： Introduction to Embedded Systems.m4a'}, page_content='respond to the inputs. Now how can we define an embedded system based on whatever we talked about'),
#  Document(metadata={'source': '/content/drive/MyDrive/ESDIPTT project book.pdf', 'producer': 'Acrobat Distiller 4.0 for Windows', 'moddate': '2003-09-13T12:35:51-10:00', 'total_pages': 209, 'creator': 'PyPDF', 'creationdate': '1999-05-17T00:46:04+00:00', 'page': 156, 'page_label': '157'}, page_content='Chapter 9: Testing \nEmbedded systems software testing shares much in common with application \nsoftware testing. Thus, much of this chapter is a summary of basic testing \nconcepts and terminology. However, some important differences exist between \napplication testing and embedded systems testing. Embedded developers often \nhave access to hardware-based test tools that are generally not used in application \ndevelopment. Also, embedded systems often have unique characteristics that \nshould be reflected in the test plan. These differences tend to give embedded \nsystems testing its own distinctive flavor. This chapter covers the basics of testing \nand test case development and points out details unique to embedded systems \nwork along the way. \nWhy Test? \nBefore you begin designing tests, it’s important to have a clear understanding of \nwhy you are testing. This understanding influences which tests you stress and \n(more importantly) how early you begin testing. In general, you test for four \nreasons:'),
#  Document(metadata={'page_label': '166', 'producer': 'Acrobat Distiller 4.0 for Windows', 'moddate': '2003-09-13T12:35:51-10:00', 'page': 165, 'creator': 'PyPDF', 'source': '/content/drive/MyDrive/ESDIPTT project book.pdf', 'creationdate': '1999-05-17T00:46:04+00:00', 'total_pages': 209}, page_content='some way to measure how well our tests are covering the code and to identify the \nsections of code that are not yet being exercised. \nThe following sections describe several techniques for measuring test coverage. \nSome are software-based, and some exploit the emulators and integrated device \nelectronics (IDE) that are often available to embedded systems engineers.')]

# %%
docs=vectordb.similarity_search_with_score(question, k=5)

# %%
import pandas as pd

_docs = pd.DataFrame(
    [(question, doc[0].page_content, doc[0].metadata.get('source'), doc[0].metadata.get('page'), doc[1]) for doc in docs],
    columns=['query', 'paragraph', 'document', 'page_number', 'relevant_score']
    )

# %%
_docs
# Out:
#                                    query  \
# 0  How to do testing in embedded system?
# 1  How to do testing in embedded system?
# 2  How to do testing in embedded system?
# 3  How to do testing in embedded system?
# 4  How to do testing in embedded system?
#
#                                            paragraph  \
# 0  respond to the inputs. Now how can we define a...
# 1  Chapter 9: Testing \nEmbedded systems software...
# 2  some way to measure how well our tests are cov...
# 3  application ran long enough, the PC would run ...
# 4  Now talking about this embedded systems again ...
#
#                                             document  page_number  \
# 0  doc/youtube/Lecture 01： Introduction to Embedd...          NaN
# 1    /content/drive/MyDrive/ESDIPTT project book.pdf        156.0
# 2    /content/drive/MyDrive/ESDIPTT project book.pdf        165.0
# 3    /content/drive/MyDrive/ESDIPTT project book.pdf         27.0
# 4  doc/youtube/Lecture 01： Introduction to Embedd...          NaN
#
#    relevant_score
# 0        0.256328
# 1        0.272554
# 2        0.284075
# 3        0.287279
# 4        0.290127

# %%
context="\n\n".join(_docs['paragraph'])

# %%
context
# Out:
# 'respond to the inputs. Now how can we define an embedded system based on whatever we talked about\n\nChapter 9: Testing \nEmbedded systems software testing shares much in common with application \nsoftware testing. Thus, much of this chapter is a summary of basic testing \nconcepts and terminology. However, some important differences exist between \napplication testing and embedded systems testing. Embedded developers often \nhave access to hardware-based test tools that are generally not used in application \ndevelopment. Also, embedded systems often have unique characteristics that \nshould be reflected in the test plan. These differences tend to give embedded \nsystems testing its own distinctive flavor. This chapter covers the basics of testing \nand test case development and points out details unique to embedded systems \nwork along the way. \nWhy Test? \nBefore you begin designing tests, it’s important to have a clear understanding of \nwhy you are testing. This understanding influences which tests you stress and \n(more importantly) how early you begin testing. In general, you test for four \nreasons:\n\nsome way to measure how well our tests are covering the code and to identify the \nsections of code that are not yet being exercised. \nThe following sections describe several techniques for measuring test coverage. \nSome are software-based, and some exploit the emulators and integrated device \nelectronics (IDE) that are often available to embedded systems engineers.\n\napplication ran long enough, the PC would run out of heap space, and the \ncomputer would crash. However, on a desktop machine with 64MB of RAM and \nvirtual swap space, this is unlikely to be a problem. On the other side, in an \nembedded system, running continuously for weeks at a time, even a small \nmemory leak is potentially disastrous. \nWho Does the Testing? \nIn many companies, the job of testing the embedded product goes to a separate \nteam of engineers and technicians because asking a designer to test his own code \nor product usually results in erratic test results. It also might lead to a “circle the \nwagons” mentality on the part of the design team, who view the testers as a \nroadblock to product release, rather than equal partners trying to prevent a \ndefective product from reaching the customer.\n\nNow talking about this embedded systems again what are these embedded systems? I already'

# %%
human_message=[HumanMessage(content=context+question)]

# %%
result=llm.invoke(system_message+human_message)

# %%
result.content
# Out:
# 'Based on the provided context, an embedded system can be defined as a computer system that is designed to perform a specific function or set of functions, often with unique characteristics and constraints, such as limited memory and resources. It is typically used in applications where reliability and efficiency are crucial, such as in automotive, medical, and industrial control systems.'

# %%
question="What is ICs?"

# %%
docs=vectordb.similarity_search_with_score(question, k=5)

import pandas as pd

_docs = pd.DataFrame(
    [(question, doc[0].page_content, doc[0].metadata.get('source'), doc[0].metadata.get('page'), doc[1]) for doc in docs],
    columns=['query', 'paragraph', 'document', 'page_number', 'relevant_score']
    )

context="\n\n".join(_docs['paragraph'])

human_message=[HumanMessage(content=context+question)]
response=llm.invoke(system_message+human_message)

# %%
response.content
# Out:
# 'ICs stand for Integrated Circuits, which are electronic circuits that are fabricated onto a single chip of semiconductor material, such as silicon. They contain a large number of components, including transistors, diodes, and resistors, that are connected together to perform a specific function.'

# %%
context
# Out:
# 'Modern IC technology is changing that fact rapidly. \nNot too long ago, companies such as Silicon Graphics and Floating Point Systems \nmade extremely expensive and complex hardware boxes that would plug into your \nDEC VAX or Data General Nova, and perform the hardware graphics and floating-\npoint support that is now taken for granted in every desktop computer. Today, you \ncan put entire systems on a single IC large enough, quantities of which can cost \nonly a few dollars. \nFor example, AMD now produces a complete PC on a single chip, the SC520. The \nSC520 is designed around a 486 microprocessor “core” with all the peripheral \ndevices that you might find in your desktop PC. Many of today’s amazingly small \nand powerful communication and computing devices — such as PDAs, cell phones, \ndigital cameras, MPEG players and so on — owe their existence to ASIC technology \nand systems-on-silicon. \n \nFigure 3.1 shows how board-level designs are migrated to both a group of ASIC\n\nDebug with ISS \nAnother possible solution is for the software team to use Instruction Set Simula \ntors (ISS) to allow them to compile their target code for their chosen microproces \nsor but execute the code on their workstations. The ISS is a program that creates \na virtual version of the microprocessor. Some ISS’s are very elaborate and main \ntain cycle-by-cycle accuracy of the target microprocessor, including cache behav\n\na complete computer inside a single chip. So whatever you need processor, memory, some IO\n\nior, pipeline behavior, and memory interface behavior. My hardware architecture \nclass at UWB uses an ISS for the Motorola MC68000 microprocessor, developed by \nPaul Lambert, Professor Alan Clements and his group at the University of Tee side, \nin Great Britain.  \nInstruction set simulators can be very complex simulation programs. At AMD, we \ndrew a distinction between the architectural simulator, which accurately mod eled \nthe processor and memory interface behavior, and the instruction set simula tor, \nwhich was fast enough for code development but could not be used to accurately \npredict software execution times for given memory configurations. Today, you can \npurchase ISS’s that are both fast and cycle-accurate. Given the power of today’s \nworkstations and PC’s, it is reasonable to expect an ISS to be able to have a \nthroughput in the range of 1 to 25 million instructions per second, certainly fast \nenough to meet the needs of most software developers.\n\nNow talking about this embedded systems again what are these embedded systems? I already'

# %% [markdown]
# MEMORY

# %%
# !pip install langgraph --quiet

# %%
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import START, MessagesState, StateGraph

workflow = StateGraph(state_schema = MessagesState)

#Define the function that calls the model
def call_model(state: MessagesState):
  system_prompt = (
      "You are a helpful assistants."
      "Answer all questions to the best of your ability."
  )
  messages = [SystemMessage(content=system_prompt)] + state["messages"]
  response = llm.invoke(messages)
  return {"messages": response}

#Define the node and edge
workflow.add_node("model", call_model)
workflow.add_edge(START, "model")

#Add simple in-memory checkpointer
memory = MemorySaver()
app = workflow.compile(checkpointer = memory)

# %%
app

# %%
app.invoke(
    {"messages": [HumanMessage(content="Translate to French: I love programming.")]},
    config={"configurable": {"thread_id":"1"}},
)
# Out:
# {'messages': [HumanMessage(content='Translate to French: I love programming.', additional_kwargs={}, response_metadata={}, id='63c5a0f8-4378-466f-ae2c-d8fda520adb2'),
#   AIMessage(content='The translation of "I love programming" to French is:\n\n"J\'adore le programmation."\n\nHowever, a more common and idiomatic way to express this in French would be:\n\n"Je suis passionné(e) par la programmation."\n\nThis translation conveys a stronger sense of enthusiasm and passion for programming.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 59, 'total_tokens': 124, 'completion_time': 0.097234423, 'completion_tokens_details': None, 'prompt_time': 0.002897479, 'prompt_tokens_details': None, 'queue_time': 0.020900919, 'total_time': 0.100131902}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_6b5c123dd9', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--afdb2747-c405-4b33-bdb4-64a01c2b46a5-0', usage_metadata={'input_tokens': 59, 'output_tokens': 65, 'total_tokens': 124})]}

# %%
app.invoke(
    {"messages": [HumanMessage(content="What did i ask you.")]},
    config={"configurable": {"thread_id":"1"}},
)
# Out:
# {'messages': [HumanMessage(content='Translate to French: I love programming.', additional_kwargs={}, response_metadata={}, id='63c5a0f8-4378-466f-ae2c-d8fda520adb2'),
#   AIMessage(content='The translation of "I love programming" to French is:\n\n"J\'adore le programmation."\n\nHowever, a more common and idiomatic way to express this in French would be:\n\n"Je suis passionné(e) par la programmation."\n\nThis translation conveys a stronger sense of enthusiasm and passion for programming.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 59, 'total_tokens': 124, 'completion_time': 0.097234423, 'completion_tokens_details': None, 'prompt_time': 0.002897479, 'prompt_tokens_details': None, 'queue_time': 0.020900919, 'total_time': 0.100131902}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_6b5c123dd9', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--afdb2747-c405-4b33-bdb4-64a01c2b46a5-0', usage_metadata={'input_tokens': 59, 'output_tokens': 65, 'total_tokens': 124}),
#   HumanMessage(content='What did i ask you.', additional_kwargs={}, response_metadata={}, id='9803fc89-3ebf-45dc-a974-455fd1efbfef'),
#   AIMessage(content='You asked me to translate the sentence "I love programming" into French.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 139, 'total_tokens': 155, 'completion_time': 0.019047912, 'completion_tokens_details': None, 'prompt_time': 0.007806352, 'prompt_tokens_details': None, 'queue_time': 0.022519565, 'total_time': 0.026854264}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_6b5c123dd9', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--b61131c7-4bf8-4531-a197-3194e8fc1ad2-0', usage_metadata={'input_tokens': 139, 'output_tokens': 16, 'total_tokens': 155})]}
